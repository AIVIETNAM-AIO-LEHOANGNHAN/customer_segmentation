# %% [markdown]
# # Khám phá và Tính toán Đặc trưng RFM (Task 7)
#
# Notebook này minh họa quá trình tính toán RFM từ tập dữ liệu đã làm sạch.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../src')
from features.rfm import load_data, filter_valid_transactions, calculate_total_price, calculate_rfm

df = load_data('../data/processed/cleaned_transactions.csv')
print(f"Initial shape: {df.shape}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import sys
#       4 sys.path.append('../src')
#
# File c:\Users\NHAN\OneDrive\AIO_Conquer_Module_2\venv\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File c:\Users\NHAN\OneDrive\AIO_Conquer_Module_2\venv\Lib\site-packages\pandas\core\config_init.py:31
#      19 import pandas._config.config as cf
#      20 from pandas._config.config import (
#      21     is_bool,
#      22     is_callable,
#    (...)     28     is_text,
#      29 )
# ---> 31 from pandas.errors import Pandas4Warning
#      33 # compute
#      35 use_bottleneck_doc = """
#      36 : bool
#      37     Use the bottleneck library to accelerate if it is installed,
#      38     the default is True
#      39     Valid values: False,True
#      40 """
#
# File c:\Users\NHAN\OneDrive\AIO_Conquer_Module_2\venv\Lib\site-packages\pandas\errors\__init__.py:12
#       8 import ctypes
#      10 from pandas._config.config import OptionError
# ---> 12 from pandas._libs.tslibs import (
#      13     IncompatibleFrequency,
#      14     OutOfBoundsDatetime,
#      15     OutOfBoundsTimedelta,
#      16 )
#      18 from pandas.util.version import InvalidVersion
#      21 class IntCastingNaNError(ValueError):
#
# File c:\Users\NHAN\OneDrive\AIO_Conquer_Module_2\venv\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/missing.pyx:1, in init pandas._libs.missing()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\NHAN\OneDrive\AIO_Conquer_Module_2\venv\Lib\site-packages\pandas\_libs\tslibs\__init__.py:40
#       1 __all__ = [
#       2     "BaseOffset",
#       3     "Day",
#    (...)     37     "tz_convert_from_utc_single",
#      38 ]
# ---> 40 from pandas._libs.tslibs import dtypes
#      41 from pandas._libs.tslibs.conversion import localize_pydatetime
#      42 from pandas._libs.tslibs.dtypes import (
#      43     Resolution,
#      44     periods_per_day,
#      45     periods_per_second,
#      46 )
#
# File pandas/_libs/tslibs/dtypes.pyx:1, in init pandas._libs.tslibs.dtypes()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# ImportError: DLL load failed while importing np_datetime: An Application Control policy has blocked this file.

# %% [markdown]
# ## 1. Lọc giao dịch hợp lệ
# Loại bỏ các dòng hủy, dòng có cờ lỗi, và loại bỏ luôn cặp mua - hủy.

# %%
valid_df = filter_valid_transactions(df)
print(f"Valid shape: {valid_df.shape}")
# Out:
# Start filtering. Initial rows: 536642
# [remove_buy_cancel_pairs] Removed 11754 rows (buy-cancel pairs).
# Finished filtering. Valid rows remaining: 388335
# Valid shape: (388335, 14)

# %% [markdown]
# ## 2. Tính Total Price và RFM

# %%
valid_df = calculate_total_price(valid_df)
rfm_table = calculate_rfm(valid_df, snapshot_date='2011-12-10')
rfm_table.head()
# Out:
# Calculating R, F, M...
#    CustomerID  Recency  Frequency  Monetary
# 0     12347.0        2          7   4310.00
# 1     12348.0       75          4   1437.24
# 2     12349.0       18          1   1457.55
# 3     12350.0      310          1    294.40
# 4     12352.0       36          6   1265.41

# %% [markdown]
# ## 3. Kiểm chứng kết quả (Test cases)
# Kiểm tra khách hàng 12346 và 12347.

# %%
test_customers = ['12346', '12347', '16446']
rfm_table[rfm_table['CustomerID'].astype(str).isin(test_customers)]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Recency, Frequency, Monetary]
# Index: []
